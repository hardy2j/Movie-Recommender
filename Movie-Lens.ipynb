# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2=pd.read_csv('/Users/y2z/Desktop/tmdb-5000-movie-dataset/tmdb_5000_movies.csv')
df1=pd.read_csv('/Users/y2z/Desktop/tmdb-5000-movie-dataset/tmdb_5000_credits.csv')

# %%
df2.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df1.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df1.columns=['id','tittle','cast','crew']
df2=df2.merge(df1,on='id')

# %%
df2.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
C=df2['vote_average'].mean()

# %%
C
# Out:
# 6.092171559442011

# %%
m=df2['vote_count'].quantile(.9)

# %%
m
# Out:
# 1838.4000000000015

# %%
q_movies=df2[df2['vote_count']>=m]

# %%
q_movies.shape
# Out:
# (481, 23)

# %%
def weighted_rating(x,m=m,C=C):
    v=x['vote_count']
    R=x['vote_average']
    return ((v/(v+m))*R)+((m/(v+m))*C)

# %%
q_movies['score']=q_movies.apply(weighted_rating,axis=1)
# Out:
# /Users/y2z/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
q_movies.sample(5)
# Out:
#          budget                                             genres  \
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 2086   18000000  [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 2096   13000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 2071   21000000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                         homepage      id  \
# 662   http://www.foxmovies.com/movies/fight-club     550
# 2086                                         NaN     772
# 24                                           NaN     254
# 2096          http://theconjuring.warnerbros.com  138843
# 2071      http://silverliningsplaybookmovie.com/   82693
#
#                                                keywords original_language  \
# 662   [{"id": 825, "name": "support group"}, {"id": ...                en
# ...

# %%
q_movies=q_movies.sort_values(by='score',ascending=False)

# %%
q_movies.head(5)
# Out:
#          budget                                             genres  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 96    160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
#
#                                           homepage     id  \
# 1881                                           NaN    278
# 662     http://www.foxmovies.com/movies/fight-club    550
# 65    http://thedarkknight.warnerbros.com/dvdsite/    155
# 3232                                           NaN    680
# 96           http://inceptionmovie.warnerbros.com/  27205
#
#                                                keywords original_language  \
# 1881  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
# ...

# %%
q_movies[['original_title','vote_average','vote_count','score']].head()
# Out:
#                 original_title  vote_average  vote_count     score
# 1881  The Shawshank Redemption           8.5        8205  8.059258
# 662                 Fight Club           8.3        9413  7.939256
# 65             The Dark Knight           8.2       12002  7.920020
# 3232              Pulp Fiction           8.3        8428  7.904645
# 96                   Inception           8.1       13752  7.863239

# %%
pop=df2.sort_values(by='popularity',ascending=False)
pop=pop.head()
plt.figure(figsize=(7,7))
sns.barplot(x='original_title',y='popularity',data=pop)
plt.xticks(rotation=45)
plt.show()

# %%
pop
# Out:
#         budget                                             genres  \
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                      homepage      id  \
# 546              http://www.minionsmovie.com/  211672
# 95          http://www.interstellarmovie.net/  157336
# 788  http://www.foxmovies.com/movies/deadpool  293660
# 94                http://marvel.com/guardians  118340
# 127               http://www.madmaxmovie.com/   76341
#
#                                               keywords original_language  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
# 95   [{"id": 83, "name": "saving the world"}, {"id"...                en
# ...

# %%
df2['overview'].head()
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(stop_words='english')
df2['overview']=df2['overview'].fillna('')
tfidf_matrix=tfidf.fit_transform(df2['overview'])

# %%
tfidf_matrix.shape
# Out:
# (4803, 20978)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim=cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
# Reverse Mapping
indices=pd.Series(df2.index,index=df2['title']).drop_duplicates()

# %%
# indices

# %%
# pd.Series(df2['title']).drop_duplicates()

# %%
def get_recommendations(title,cosine_sim=cosine_sim):
    idx=indices[title]
    sim_scores=list(enumerate(cosine_sim[idx]))
    sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
    sim_scores=sim_scores[1:11]
    movie_indices=[i[0] for i in sim_scores]
    return df2['title'].iloc[movie_indices]

# %%
get_recommendations('Letters to Juliet')
# Out:
# 2661                 Romeo + Juliet
# 3954                   Chain Letter
# 3069                  Danny Collins
# 3631             Heavenly Creatures
# 2527    National Lampoon's Vacation
# 1582            Message in a Bottle
# 3263                         Easy A
# 2244          The Cold Light of Day
# 2938                 The Ladies Man
# 1043              Miss Congeniality
# Name: title, dtype: object

# %%
# from ast import literal_eval

# %%
# features=['cast','crew','keywords','genres']
# for feature in features:
#     df2[feature]=df2[feature].apply(literal_eval)

# %%
df2.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'tittle', 'cast', 'crew'],
#       dtype='object')

# %%
# def get_director(x):
#     for i in x:
#         if(i['job']=='Director'):
#             return i['name']
#     return np.nan

# %%
# def get_list(x):
#     if isinstance(x,list):
#         names=[i['name'] for i in x]
#         if len(names)>3:
#             names=names[:3]
#         return names
#     return[]

# %%
# df2['director']=df2['crew'].apply(get_director)

# %%
# df2.head()

# %%
# features=['cast','keywords','genres']
# for feature in features:
#     df2[feature]=df2[feature].apply(get_list)

# %%
# df2[['title','cast','director','keywords','genres']].head(3)

# %%
# def clean_data(x):
#     if isinstance(x,list):
#         return (str.lower(i.replace(" ","")) for i in x)
#     else:
#         if isinstance(x,str):
#             return (str.lower(x.replace(" ","")))
#         else:
#             return ''

# %%
# features=['cast','crew','director','genres']
# for feature in features:
#     df2[feature]=df2[feature].apply(clean_data)

# %%
# df2[['title','cast','director','keywords','genres']].head(3)

# %%
# def create_soup(x):
#     return ' '.join(x['keywords'])+' '+' '.join(x['cast'])+' '+x['director']+' '+' '.join(x['genres'])
# df2['soup']=df2.apply(create_soup,axis=1)

# %%
# df2.head()

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# %%
# count=CountVectorizer(stop_words='english')
# count_matrix=count.fit_transform(df2['soup'])
# from sklearn.metrics.pairwise import cosine_similarity
# cosine_sim2=cosine_similarity(count_matrix,count_matrix)

# %%
# df2=df2.reset_index()

# %%
# indices=pd.Series(df2.index,index=df2['title'])

# %%
# get_recommendations('When a Stranger Calls',cosine_sim2)

# %%
ratings=pd.read_csv('/Users/y2z/Desktop/ratings_small.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
# import joblib
# from surprise import Reader,Dataset,SVD,evaluate
# reader=Reader()

# %%
# data=Dataset.load_from_df(ratings[['userId','movieId','rating']],reader)

# %%
# data.split(n_folds=5)

# %%
# svd=SVD()

# %%
# evaluate(svd,data,measures=['RMSE','MAE'])

# %%
# trainset=data.build_full_trainset()

# %%
# svd.fit(trainset)

# %%
# ratings[ratings['userId']==1]

# %%
# svd.predict(2,31,4)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(stop_words='english')
df2['overview']=df2['overview'].fillna("")
tfidf_matrix=tfidf.fit_transform(df2['overview'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim=cosine_similarity(tfidf_matrix,tfidf_matrix)
indices=pd.Series(df2.index,index=df2['title'])

# %%
def get_recommendations(title,cosine_sim=cosine_sim):
    idx=indices[title]
    sim_scores=list(enumerate(cosine_sim[idx]))
    sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
    sim_scores=sim_scores[1:11]
    movie_indices=[i[0] for i in sim_scores]
    return df2['title'].iloc[movie_indices]

# %%
get_recommendations('Before Sunrise')
# Out:
# 381     The Nutcracker: The Untold Story
# 3064                    Run, Fatboy, Run
# 4088                       Before Sunset
# 1934                     Say It Isn't So
# 1680         Savva. Heart of the Warrior
# 4661                      The Big Parade
# 4640         Love and Other Catastrophes
# 2872                From Justin to Kelly
# 2233                          Little Boy
# 967                            Hereafter
# Name: title, dtype: object

# %%
from ast import literal_eval

# %%
features=['cast','crew','keywords','genres']
for feature in features:
    df2[feature]=df2[feature].apply(literal_eval)

# %%
df2.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'tittle', 'cast', 'crew'],
#       dtype='object')

# %%
df2[feature][0]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def get_director(x):
    for i in x:
        if i['job']=='Director':
            return i['name']
    return np.nan

# %%
df2.crew[0]
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '54491cb70e0a267480001bd0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Supervising Sound Editor',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '539c4a4cc3a36810c9002101',
#   'department': 'Production',
#   'gender': 1,
#   'id': 1262,
#   'job': 'Casting',
#   'name': 'Mali Finn'},
#  {'credit_id': '5544ee3b925141499f0008fc',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 1729,
#   'job': 'Original Music Composer',
#   'name': 'James Horner'},
# ...

# %%
def get_list(x):
    if isinstance(x,list):
        names=[i['name'] for i in x]
        if len(names)>3:
            names=names[:3]
        return names
    return []

# %%
df2['director']=df2['crew'].apply(get_director)

# %%
df2.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'tittle', 'cast', 'crew', 'director'],
#       dtype='object')

# %%
df2.sample()
# Out:
#       budget                                             genres  \
# 4503  522360  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
#
#                                  homepage      id  \
# 4503  https://www.facebook.com/music4mali  324322
#
#                                         keywords original_language  \
# 4503  [{'id': 187056, 'name': 'woman director'}]                fr
#
#                        original_title  \
# 4503  They Will Have to Kill Us First
#
#                                                overview  popularity  \
# 4503  In 2012, jihadists took control of northern Ma...    0.071349
#
#                                    production_companies        ...         \
# 4503  [{"name": "Spring Films", "id": 9158}, {"name"...        ...
#
#                                        spoken_languages    status  tagline  \
# 4503  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released      NaN
#
#                                 title vote_average vote_count  \
# ...

# %%
features=['cast','keywords','genres']
for feature in features:
    df2[feature]=df2[feature].apply(get_list)

# %%
df2[['title','director','cast','keywords','genres']].head(3)
# Out:
#                                       title        director  \
# 0                                    Avatar   James Cameron
# 1  Pirates of the Caribbean: At World's End  Gore Verbinski
# 2                                   Spectre      Sam Mendes
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]
#
#                               keywords                        genres
# 0   [culture clash, future, space war]  [Action, Adventure, Fantasy]
# 1   [ocean, drug abuse, exotic island]  [Adventure, Fantasy, Action]
# 2  [spy, based on novel, secret agent]    [Action, Adventure, Crime]

# %%
def clean_data(x):
    if isinstance(x,list):
        return [str.lower(i.replace(" ","")) for i in x]
    else:
        if isinstance(x,str):
            return str.lower(x.replace(" ",""))
        else:
            return''

# %%
features=['cast','keywords','genres','director']
for feature in features:
    df2[feature]=df2[feature].apply(clean_data)
def create_soup(x):
    return ' '.join(x['keywords'])+' '+' '.join(x['cast'])+' '+x['director']+' '+' '.join(x['genres'])
df2['soup']=df2.apply(create_soup,axis=1
                     )

# %%
df2[['cast','keywords','genres','director','soup']].head(3)
# Out:
#                                             cast  \
# 0  [samworthington, zoesaldana, sigourneyweaver]
# 1     [johnnydepp, orlandobloom, keiraknightley]
# 2      [danielcraig, christophwaltz, léaseydoux]
#
#                            keywords                        genres  \
# 0  [cultureclash, future, spacewar]  [action, adventure, fantasy]
# 1  [ocean, drugabuse, exoticisland]  [adventure, fantasy, action]
# 2  [spy, basedonnovel, secretagent]    [action, adventure, crime]
#
#         director                                               soup
# 0   jamescameron  cultureclash future spacewar samworthington zo...
# 1  goreverbinski  ocean drugabuse exoticisland johnnydepp orland...
# 2      sammendes  spy basedonnovel secretagent danielcraig chris...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count=CountVectorizer(stop_words='english')
count_matrix=count.fit_transform(df2['soup'])

# %%
count_matrix
# Out:
# <4803x11520 sparse matrix of type '<class 'numpy.int64'>'
# 	with 42935 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim2=cosine_similarity(count_matrix,count_matrix)
df2=df2.reset_index()

# %%
indices=pd.Series(df2.index,index=df2['title']).drop_duplicates()

# %%
get_recommendations('Mean Girls',cosine_sim2)
# Out:
# 1778                           Freaky Friday
# 2559    Confessions of a Teenage Drama Queen
# 2485                             The Cookout
# 1184                                17 Again
# 1906                      The Girl Next Door
# 2101                            White Chicks
# 2938                          The Ladies Man
# 2979                             Bring It On
# 3263                                  Easy A
# 3915                                Trippin'
# Name: title, dtype: object
